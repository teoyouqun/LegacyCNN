# %%
from torchsummary import summary
from python_lib.ecapa_classifier import *
from python_lib.trainers import *
import torch
import numpy as np
import os
import h5py
from torch.utils.data import DataLoader, TensorDataset, Dataset
from torch.utils.data import random_split
# Out:
# SpeechBrain could not find any working torchaudio backend. Audio files may fail to load. Follow this link for instructions and troubleshooting: https://speechbrain.readthedocs.io/en/latest/audioloading.html
# SpeechBrain could not find any working torchaudio backend. Audio files may fail to load. Follow this link for instructions and troubleshooting: https://speechbrain.readthedocs.io/en/latest/audioloading.html

# %%
model = ECAPA_TDNN(input_size = 2, channels=[512,512,512,512,1024], lin_neurons=192, out_neurons=6, device = "cuda")
#model = ECAPA_TDNN(input_size = 8, lin_neurons=6, device = "cpu")
model = model.train()
input_feats = torch.rand([10,2,512])
#print(input_feats)
output = model(input_feats)
#output.shape
# Out:
# tensor([[[-2.4316e-01,  7.1521e-01,  1.8682e-01,  ..., -2.6962e-01,
#           -5.3819e-01,  1.3047e+00],
#          [-2.9307e-01, -2.9307e-01, -2.9307e-01,  ..., -2.9307e-01,
#           -2.9307e-01, -2.9307e-01],
#          [-3.9375e-01,  1.1025e+00, -3.9375e-01,  ..., -3.9375e-01,
#           -3.9375e-01, -3.9375e-01],
#          ...,
#          [-2.2069e-01, -3.5501e-01, -1.7592e+00,  ..., -4.6521e-01,
#           -1.2114e+00,  1.8016e-02],
#          [-8.7835e-01, -8.7835e-01,  2.4448e-01,  ..., -8.7835e-01,
#            1.8845e-01,  1.4939e+00],
#          [ 4.9052e-01,  9.4809e-01,  3.7388e-01,  ...,  4.7003e-01,
#            2.3016e-01, -6.8576e-01]],
#
#         [[ 4.6673e-01,  3.5996e-01,  1.1529e+00,  ..., -1.8675e+00,
#            1.2041e+00, -4.4051e-01],
#          [-2.9307e-01, -2.9307e-01, -2.9307e-01,  ..., -2.9307e-01,
#           -2.9307e-01, -2.9307e-01],
#          [-3.9375e-01,  5.7662e-01, -3.9375e-01,  ..., -3.9375e-01,
#            2.8256e+00, -3.9375e-01],
#          ...,
#          [-1.1797e+00,  2.4227e-01, -1.0826e+00,  ..., -1.4128e+00,
#            1.1692e+00, -1.2398e+00],
#          [-8.7835e-01,  3.1938e-01, -8.7835e-01,  ..., -8.7835e-01,
#            6.3837e-01, -3.4978e-01],
#          [ 1.5361e+00,  7.2264e-01,  1.4805e+00,  ...,  1.1763e+00,
#           -6.3948e-01, -4.5977e-01]],
#
#         [[-3.5904e-01, -2.4897e-01, -2.2300e-01,  ..., -5.8905e-01,
#            1.6710e-01,  9.6523e-01],
#          [-2.9307e-01, -2.9307e-01, -2.9307e-01,  ..., -2.9307e-01,
#           -2.9307e-01, -2.9307e-01],
#          [-3.9375e-01,  2.7035e+00, -3.9375e-01,  ..., -3.9375e-01,
#           -3.9375e-01,  2.6137e+00],
#          ...,
#          [-1.0979e+00, -6.4743e-01, -7.5956e-01,  ..., -7.9287e-01,
#            1.2513e+00,  2.7732e+00],
#          [-8.7835e-01, -8.7835e-01, -8.7835e-01,  ...,  2.4221e+00,
#            2.6539e-01, -6.2220e-01],
#          [-1.2546e-01,  1.1091e+00,  3.7890e-02,  ..., -3.8090e-01,
#            6.1719e-01, -6.1897e-01]],
#
#         ...,
#
#          [-0.7597,  0.2106,  0.1861,  ..., -0.7597,  2.4596, -0.1335],
#          ...,
#          [-1.5350,  1.0572, -1.4380,  ..., -1.5707,  1.5028, -1.5952],
#          [-1.0708, -0.0077, -1.2055,  ..., -0.8882,  0.3113, -0.3794],
#          [ 2.0188,  1.0707,  2.5620,  ...,  0.8542, -0.6564, -0.7819]],
#
#         [[-0.6657, -0.5556, -0.5296,  ..., -0.5223, -0.1395,  0.6586],
#          [-0.6339, -0.6339, -0.6339,  ..., -0.2810,  0.8331, -0.0412],
#          [ 0.4957,  2.3361, -0.7612,  ..., -0.3379, -0.3059,  2.2462],
#          ...,
#          [-1.4516, -0.9192, -0.2948,  ..., -0.8084,  0.8976,  3.2378],
#          [-0.8414, -0.3221, -1.2010,  ...,  2.0995,  0.5611,  1.3937],
#          [-0.4558,  0.7788, -0.2924,  ...,  2.0569,  0.2869,  0.3341]],
#
#         ...,
#
#         [[-1.2270,  1.6695, -0.8127,  ..., -1.4021, -1.0017,  0.4554],
#          [ 2.9730, -0.6338,  0.4467,  ..., -0.6338,  3.6691, -0.6338],
#          [-0.3599,  1.4693,  0.2967,  ..., -0.7608,  1.1150, -0.7608],
#          ...,
#          [-2.1145, -0.5488, -2.1145,  ..., -1.8667,  3.4653,  1.7631],
#          [ 0.7076,  0.2908,  0.5040,  ...,  1.4659,  1.1321, -1.2028],
#          [-0.3221,  0.4277,  1.2753,  ..., -0.9148, -0.9901,  0.1932]],
#
#         [[-1.0044,  0.9662,  1.3585,  ...,  0.2181,  1.7194, -0.3872],
#          [-0.3147, -0.6281, -0.6281,  ...,  0.5916, -0.6281,  0.0862],
#          [-0.7573, -0.7573,  1.2780,  ..., -0.7573,  1.2350, -0.7573],
#          ...,
#          [-1.1427,  0.9236,  0.1640,  ..., -0.8136, -0.9693, -0.1549],
#          [ 0.1342, -1.2029, -1.2029,  ..., -0.6797,  1.6551,  1.2669],
#          [-1.4432,  0.2833,  0.6019,  ...,  1.0902,  1.2975,  1.5962]],
#
#         [[ 0.8048, -0.1887,  0.0955,  ...,  1.2573,  2.6173, -0.9806],
#          [-0.3319, -0.6312, -0.6312,  ..., -0.2895, -0.6312,  0.6637],
#          [ 0.2507, -0.3758, -0.7597,  ...,  0.9990, -0.7597,  0.4684],
#          ...,
#          [ 1.7737, -1.0614,  0.1579,  ...,  0.7640, -1.1855,  0.2358],
#          [-1.2053, -1.2053,  1.0280,  ..., -0.7284,  0.1850,  0.0557],
#          [-0.9657,  0.2015,  0.5297,  ...,  0.1603,  1.2180, -0.2251]]],
#        grad_fn=<AddBackward0>)
# tensor([[[-8.9020e-01,  1.3746e+00, -4.6023e-01,  ...,  2.4854e-02,
#           -2.7336e-01,  9.0664e-01],
#          [-9.8911e-01, -8.7561e-02, -8.0899e-01,  ..., -6.4807e-02,
#           -4.4544e-01, -9.8911e-01],
#          [ 1.0024e-01,  1.5486e+00, -4.8391e-01,  ..., -1.1183e+00,
#           -4.2446e-01,  1.0821e+00],
#          ...,
#          [ 8.6395e-01, -2.3864e-01, -2.3767e+00,  ...,  5.1634e-02,
#           -1.3004e+00,  4.4023e-01],
#         [ 0.0078, -0.0326,  0.0496,  ...,  0.0096, -0.0502, -0.0145],
#         [ 0.0066, -0.0085, -0.0012,  ..., -0.1094,  0.0485, -0.0111]],
#        grad_fn=<SumBackward1>)
# tensor([[1.0552, 1.0428, 1.0055,  ..., 1.0746, 1.0077, 0.9964],
#         [0.9320, 0.9728, 0.9648,  ..., 1.0524, 1.0933, 1.0537],
#         [1.0427, 0.9945, 0.9902,  ..., 1.0788, 0.9734, 0.9235],
#         ...,
#         [1.0159, 1.0312, 1.0362,  ..., 1.0343, 0.9431, 1.0511],
#         [1.0047, 0.9944, 0.9799,  ..., 1.0285, 0.9193, 0.9353],
#         [0.9644, 0.9544, 1.0484,  ..., 0.8401, 1.0298, 0.9918]],
#        grad_fn=<SqrtBackward0>)
# After ASP_BN: torch.Size([10, 2048, 1])
# After FC: torch.Size([10, 192, 1])
# After view: torch.Size([10, 192])
# Classifier: x.shape = torch.Size([10, 192]), weight.shape = torch.Size([6, 192])
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[8], line 6
#       4 input_feats = torch.rand([10,2,512])
#       5 #print(input_feats)
# ----> 6 output = model(input_feats)
#       7 #output.shape
#
# File ~/PyEnv/ecapa_venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/PyEnv/ecapa_venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/Git/LegacyCNN/python_lib/ecapa_classifier.py:617, in ECAPA_TDNN.forward(self, x, lengths)
#     615 x = x.view(x.shape[0], -1)
#     616 print(f"After view: {x.shape}")
# --> 617 x = self.probabilities(x)
#     619 #x = F.softmax(x, dim=2)
#     620 return x
#
# File ~/PyEnv/ecapa_venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/PyEnv/ecapa_venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/Git/LegacyCNN/python_lib/ecapa_classifier.py:682, in Classifier.forward(self, x)
#     680 if self.metrics_type == "cosine":
#     681     print(f"Classifier: x.shape = {x.shape}, weight.shape = {self.weight.shape}")
# --> 682     x = F.linear(F.normalize(x), F.normalize(self.weight))
#     683     return x
#     684 elif self.metrics_type == "cdist":
#
# RuntimeError: Expected all tensors to be on the same device, but found at least two devices, cpu and cuda:0! (when checking argument for argument mat2 in method wrapper_CUDA_mm)

# %%
with h5py.File('../RadChar-Tiny.h5', 'r') as f:
    # Print the dataset names
    print(list(f.keys())) # OUT: ['iq', 'labels']
    
    # Get a reference to the dataset
    h5_iqs = f['iq'] 
    h5_labels = f['labels'] 
    
    # Print the shape of the dataset
    # print(h5_iqs.shape) # OUT: (50000, 512)
    # print(h5_labels.shape) # OUT: (50000,)
    
    # Print the contents of the dataset
    loaded_h5_iqs = h5_iqs[...] # IQ data
    loaded_h5_labels = h5_labels[...] # Label data

# Temporary fix to deal with IQ data
temp_iq_data = torch.tensor(loaded_h5_iqs)
t_iq_real = temp_iq_data.real.float()
t_iq_imag = temp_iq_data.imag.float()
t_iq_data = torch.stack([t_iq_real, t_iq_imag], dim = 1)
print(t_iq_data.shape)

index = loaded_h5_labels['index']
signal_type = loaded_h5_labels['signal_type']
t_index = torch.tensor(index, dtype=torch.int64)
t_signal_type = torch.tensor(signal_type, dtype=torch.int64)
combined = torch.stack([t_index, t_signal_type], dim=1)
dataset = TensorDataset(t_iq_data, combined)
# Out:
# ['iq', 'labels']
# torch.Size([50000, 2, 512])

# %%
# total size
total_size = 50000
train_size = 45000
val_size = total_size - train_size
# batch size
batch_size = 32

# split
train_dataset, val_dataset = random_split(
    dataset, [train_size, val_size],
    generator=torch.Generator().manual_seed(42)  # for reproducibility
)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# %%
model.train()
training = BaseTrainer(model)
training._train(train_loader)
# Out:
# Epoch: 0/49
# -----------------------------
# tensor([[[-0.5168,  1.0616,  1.0609,  ...,  0.9772, -0.5168, -0.5168],
#          [ 4.4935, -0.3986, -0.3986,  ..., -0.3986,  5.5650, -0.3986],
#          [ 1.5539,  0.7000, -0.3954,  ..., -0.3954,  4.4069,  0.7315],
#          ...,
#          [-0.0679,  3.6223,  2.3306,  ..., -0.4423,  1.8804,  1.5554],
#          [ 1.7061, -0.4356, -0.4356,  ...,  1.3219,  2.5356, -0.4356],
#          [-0.5427, -0.5427,  1.2030,  ..., -0.5427, -0.5427,  4.1130]],
#
#         [[-0.0134, -0.5168, -0.0416,  ..., -0.4526, -0.1487, -0.5168],
#          [-0.3986, -0.1213, -0.3986,  ..., -0.2096, -0.3986, -0.0495],
#          [-0.1651,  0.0160, -0.2238,  ..., -0.3954, -0.3954, -0.1245],
#          ...,
#          [ 0.1978, -0.2730, -0.1055,  ..., -0.4423, -0.4423, -0.3687],
#          [-0.4356, -0.4356, -0.4356,  ..., -0.4356, -0.1548, -0.0644],
#          [-0.2177, -0.2596, -0.3668,  ..., -0.4927,  0.1580, -0.5427]],
#
#         [[-0.4039, -0.3088, -0.5168,  ..., -0.4211, -0.5168, -0.4622],
#          [-0.3986,  0.0426, -0.2413,  ..., -0.0153, -0.3986, -0.3986],
#          [-0.3954,  0.2291, -0.3954,  ...,  0.7886, -0.3954, -0.3954],
#          ...,
#          [-0.4423, -0.4423, -0.4423,  ...,  0.6181, -0.3354, -0.4423],
#          [-0.4356, -0.4356, -0.4356,  ..., -0.4356, -0.4356,  0.2783],
#          [-0.5427, -0.2651,  0.1773,  ..., -0.4134, -0.5427, -0.5427]],
#
#         ...,
#
#         [[-0.4395, -0.3139, -0.4435,  ..., -0.2879, -0.3903, -0.3988],
#          [-0.3986, -0.3986, -0.3986,  ..., -0.3986, -0.3986, -0.3986],
#          [-0.3954, -0.3490, -0.3954,  ..., -0.3954, -0.3954, -0.3754],
#          ...,
#          [-0.4423, -0.3990, -0.4423,  ..., -0.3580, -0.4423, -0.4360],
#          [-0.4356, -0.4356, -0.4356,  ..., -0.4356, -0.4356, -0.4046],
#          [-0.3225, -0.3395, -0.3768,  ..., -0.3941, -0.3194, -0.3730]],
#
#         [[ 1.4216, -0.5168,  3.4819,  ..., -0.5168, -0.0603, -0.5168],
#          [-0.3986, -0.3986, -0.3986,  ...,  3.4781,  0.6109,  1.7458],
#          [ 1.7722, -0.3954,  3.2312,  ...,  2.3074, -0.3954,  0.9136],
#          ...,
#          [-0.4423, -0.3729,  2.2311,  ...,  2.7429,  0.7621, -0.4423],
#          [ 2.7401, -0.4356, -0.4356,  ...,  1.3339, -0.4356, -0.0997],
#          [-0.0460,  0.4004,  1.1861,  ..., -0.5427, -0.4429, -0.5427]],
#
#         [[-0.4471, -0.2895, -0.4553,  ..., -0.5168, -0.4497, -0.5168],
#          [-0.3986,  0.0402, -0.3986,  ..., -0.3986, -0.0827, -0.3283],
#          [-0.3954, -0.1833, -0.3954,  ..., -0.3954, -0.2981, -0.3954],
#          ...,
#          [-0.0272, -0.3315, -0.4423,  ..., -0.3822, -0.3479, -0.4423],
#          ...,
#          [-3.6309e-01, -3.0543e-02, -9.8589e-01,  ..., -9.2580e-01,
#           -6.1913e-01, -9.8589e-01],
#          [-9.2525e-01, -6.3352e-01,  1.5531e-01,  ..., -3.5254e-01,
#           -9.2525e-01, -7.8690e-01],
#          [-8.0338e-01, -1.0975e+00, -4.4471e-01,  ..., -1.0975e+00,
#           -5.2116e-01, -1.0975e+00]]], device='cuda:0', grad_fn=<AddBackward0>)
# tensor([[[ 2.1707,  1.3390,  4.2429,  ...,  6.6743, -1.2958,  0.0069],
#          [ 4.6653, -0.7335,  2.3736,  ...,  0.1068,  6.2860, -0.9364],
#          [ 2.9846,  2.9304,  0.6733,  ..., -1.3203,  4.6862,  2.3266],
#          ...,
#          [-0.9928,  3.8192,  2.9654,  ...,  0.4632,  0.9556,  1.3024],
#          [ 1.7969,  2.5155, -0.2546,  ...,  4.8247,  2.8840, -0.6337],
#          [ 0.0518,  0.3644,  0.3546,  ...,  1.6086, -1.0413,  5.8195]],
#
#         [[-0.1939,  0.0955, -0.7974,  ..., -0.9261, -0.3502,  0.3113],
#          [-0.9213,  0.8339,  0.1264,  ..., -0.1189, -0.5225,  0.0209],
#          [-0.9767, -0.5156, -1.1275,  ..., -1.0436, -0.2122, -0.3500],
#          ...,
#          [-0.0290,  0.3056, -0.7477,  ...,  2.0459, -0.9934, -0.2258],
#          [-0.3054, -1.2867, -0.7965,  ..., -0.6042, -0.0132, -0.3343],
#          [ 1.4855,  0.2134,  0.1635,  ..., -1.2636, -0.4831, -1.2296]],
#
#         [[-1.1865,  0.6230, -1.2994,  ..., -0.8277, -0.9309,  0.0129],
#          [-0.5200, -0.3555, -1.2281,  ..., -0.6946, -0.3836, -0.8490],
#          [-0.6080,  0.0154, -1.3055,  ...,  0.2930, -0.8409, -0.8312],
#          ...,
#          [ 1.2059, -1.2311, -1.2369,  ...,  0.3551,  0.2436, -0.6210],
#          [-1.3158, -0.4613, -0.6919,  ..., -0.1882, -0.0309,  0.6379],
#          [-1.4333, -0.8198,  0.1696,  ..., -1.3040, -1.4179, -1.4333]],
#
#         ...,
#
#         [[-0.5997, -1.0710, -0.7724,  ..., -1.0860, -0.8128, -1.1560],
#          [-0.9261, -0.4668, -0.5890,  ..., -0.5074, -0.3209, -0.5639],
#          [-0.5852, -0.8066, -1.2153,  ..., -0.9278, -0.5026, -1.2573],
#          ...,
#          [-1.1612, -1.2534, -1.1053,  ..., -1.2123, -1.2967, -0.9831],
#          [-0.9228, -1.1172, -0.7523,  ..., -0.9809, -1.3274, -1.0572],
#          [-0.8898, -1.0399, -1.2901,  ..., -1.3074, -1.0197, -1.2863]],
#
#         [[ 1.1899,  0.0755,  5.4295,  ..., -0.9085, -0.1912, -1.3221],
#          [-0.5992, -0.0946, -0.1491,  ...,  4.9307, -0.3572,  1.6270],
#          [ 2.0218, -0.2770,  4.3655,  ...,  1.3952, -0.8643,  0.0330],
#          ...,
#          [-0.1061,  1.0906,  2.8596,  ...,  1.8419,  1.5407, -0.0681],
#          [ 3.1387, -0.2342, -0.2024,  ...,  2.1851,  0.1207, -0.9987],
#          [ 1.5720,  0.6947,  0.8052,  ..., -1.3714,  1.5954, -0.4056]],
#
#         [[ 0.7259, -0.6913, -0.6175,  ..., -1.2689, -0.8802, -1.2920],
#          [ 0.6937,  0.0715, -0.8235,  ..., -0.2826, -0.5347, -0.3773],
#          [ 0.2595, -1.0340, -1.2906,  ..., -0.8997, -0.9967,  0.3972],
#          ...,
#          [-0.6726, -0.3400, -1.2954,  ..., -1.2353, -0.9286, -0.7104],
#          [-1.0199, -1.0275, -0.0762,  ..., -0.7465, -0.4175, -0.6321],
#          [-0.6767, -1.4390, -0.0859,  ..., -0.8897, -0.1619, -0.5805]]],
#        device='cuda:0', grad_fn=<AddBackward0>)
# tensor([[ 0.0053,  0.8476,  0.5440,  ..., -0.7412,  1.5284, -1.0372],
#         [ 0.0918, -0.1598, -0.0753,  ...,  0.1908, -0.3443,  0.3517],
#         [-0.0303, -0.0771, -0.1031,  ...,  0.1825, -0.2997,  0.1054],
#         ...,
#         [ 0.2835, -0.4202, -0.3371,  ...,  0.2203, -0.3801,  0.5113],
#         [-0.1489,  0.3187,  0.1642,  ..., -0.5668,  0.3935, -0.8401],
#         [ 0.0745, -0.2016, -0.0471,  ...,  0.3938, -0.3470,  0.5399]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# tensor([[1.7381, 1.8496, 2.0066,  ..., 0.8146, 1.8090, 0.1719],
#         [0.8270, 0.4673, 0.5851,  ..., 0.9333, 0.1421, 0.9176],
#         [0.8457, 0.5202, 0.6480,  ..., 1.0451, 0.2436, 0.9928],
#         ...,
#         [0.5689, 0.2983, 0.4072,  ..., 0.7172, 0.0675, 0.5651],
#         [1.1362, 1.2006, 1.2488,  ..., 0.8197, 0.9472, 0.5886],
#         [0.7490, 0.4611, 0.5641,  ..., 0.9614, 0.1412, 0.9126]],
#        device='cuda:0', grad_fn=<SqrtBackward0>)
# After ASP_BN: torch.Size([32, 2048, 1])
# After FC: torch.Size([32, 192, 1])
# After view: torch.Size([32, 192])
# Classifier: x.shape = torch.Size([32, 192]), weight.shape = torch.Size([6, 192])
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[11], line 3
#       1 model.train()
#       2 training = BaseTrainer(model)
# ----> 3 training._train(train_loader)
#
# File ~/Git/LegacyCNN/python_lib/trainers.py:47, in BaseTrainer._train(self, train_loader, loss_function, num_epochs, device)
#      44 preds = model(data)
#      45 # print("preds: ",preds)
#      46 # print("target: ", target)
# ---> 47 loss = loss_function(preds, target)
#      48 loss.backward()
#      49 loss_history.append(loss.data.item())
#
# File ~/PyEnv/ecapa_venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/PyEnv/ecapa_venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/PyEnv/ecapa_venv/lib/python3.10/site-packages/torch/nn/modules/loss.py:251, in NLLLoss.forward(self, input, target)
#     250 def forward(self, input: Tensor, target: Tensor) -> Tensor:
# --> 251     return F.nll_loss(
#     252         input,
#     253         target,
#     254         weight=self.weight,
#     255         ignore_index=self.ignore_index,
#     256         reduction=self.reduction,
#     257     )
#
# File ~/PyEnv/ecapa_venv/lib/python3.10/site-packages/torch/nn/functional.py:3158, in nll_loss(input, target, weight, size_average, ignore_index, reduce, reduction)
#    3156 if size_average is not None or reduce is not None:
#    3157     reduction = _Reduction.legacy_get_string(size_average, reduce)
# -> 3158 return torch._C._nn.nll_loss_nd(
#    3159     input, target, weight, _Reduction.get_enum(reduction), ignore_index
#    3160 )
#
# RuntimeError: 0D or 1D target tensor expected, multi-target not supported

# %%
from python_lib.loaders import *
torch.cuda.empty_cache()

# %%
a = RadChar_Dataset(phase="train", dir_dataset="../RadChar-Tiny.h5")
a[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 a = RadChar_Dataset(phase="train", dir_dataset="../RadChar-Tiny.h5")
#       2 a[0]
#
# NameError: name 'RadChar_Dataset' is not defined
