# %%
from torchsummary import summary
from python_lib.ecapa_classifier import *
from python_lib.trainers import *
import torch
import numpy as np
import os
import h5py
from torch.utils.data import DataLoader, TensorDataset
from torch.utils.data import random_split

# %%
model = ECAPA_TDNN(input_size = 8, channels=[8,8,8,8,16], lin_neurons=6, device = "cpu")
#model = ECAPA_TDNN(input_size = 8, lin_neurons=6, device = "cpu")
model = model.train()
input_feats = torch.rand([10,8,64])
#print(input_feats)
#output = model(input_feats)
#output.shape

# %%
with h5py.File('../RadChar-Tiny.h5', 'r') as f:
    # Print the dataset names
    print(list(f.keys())) # OUT: ['iq', 'labels']
    
    # Get a reference to the dataset
    h5_iqs = f['iq'] 
    h5_labels = f['labels'] 
    
    # Print the shape of the dataset
    # print(h5_iqs.shape) # OUT: (50000, 512)
    # print(h5_labels.shape) # OUT: (50000,)
    
    # Print the contents of the dataset
    loaded_h5_iqs = h5_iqs[...] # IQ data
    loaded_h5_labels = h5_labels[...] # Label data

# Temporary fix to deal with IQ data
temp_iq_data = torch.tensor(loaded_h5_iqs)
t_iq_data = temp_iq_data.reshape(-1,8,64)
t_iq_data = t_iq_data.abs().float()


index = loaded_h5_labels['index']
signal_type = loaded_h5_labels['signal_type']
t_index = torch.tensor(index, dtype=torch.int64)
t_signal_type = torch.tensor(signal_type, dtype=torch.int64)
combined = torch.stack([t_index, t_signal_type], dim=1)
dataset = TensorDataset(t_iq_data, combined)
# Out:
# ['iq', 'labels']

# %%
# total size
total_size = 50000
train_size = 45000
val_size = total_size - train_size
# batch size
batch_size = 64

# split
train_dataset, val_dataset = random_split(
    dataset, [train_size, val_size],
    generator=torch.Generator().manual_seed(42)  # for reproducibility
)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# %%
model.train()
training = BaseTrainer(model)
training._train(train_dataset)
# Out:
# Epoch: 0/49
# -----------------------------
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/Git/LegacyCNN/python_lib/ecapa_classifier.py:584, in ECAPA_TDNN.forward(self, x, lengths)
#     583 try:
# --> 584     x = layer(x, lengths=lengths)
#     585 except TypeError:
#
# File ~/PyEnv/ecapa_venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/PyEnv/ecapa_venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#
# TypeError: TDNNBlock.forward() got an unexpected keyword argument 'lengths'
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[63], line 3
#       1 model.train()
#       2 training = BaseTrainer(model)
# ----> 3 training._train(train_dataset)
#
# File ~/Git/LegacyCNN/python_lib/trainers.py:44, in BaseTrainer._train(self, train_loader, loss_function, num_epochs, device)
#      41 target = Variable(label.to(device))
#      43 optimiser.zero_grad()
# ---> 44 preds = model(data)
#      45 # print("preds: ",preds)
#      46 # print("target: ", target)
#      47 loss = loss_function(preds, target)
#
# File ~/PyEnv/ecapa_venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/PyEnv/ecapa_venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/Git/LegacyCNN/python_lib/ecapa_classifier.py:586, in ECAPA_TDNN.forward(self, x, lengths)
#     584     x = layer(x, lengths=lengths)
#     585 except TypeError:
# --> 586     x = layer(x)
#     587 print(x)
#     588 xl.append(x)
#
# File ~/PyEnv/ecapa_venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/PyEnv/ecapa_venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/Git/LegacyCNN/python_lib/ecapa_classifier.py:107, in TDNNBlock.forward(self, x)
#     105 x = self.conv(x)
#     106 x = self.activation(x)
# --> 107 y = self.norm(x)
#     108 return y
#
# File ~/PyEnv/ecapa_venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/PyEnv/ecapa_venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/PyEnv/ecapa_venv/lib/python3.12/site-packages/speechbrain/nnet/normalization.py:101, in BatchNorm1d.forward(self, x)
#      98 elif not self.skip_transpose:
#      99     x = x.transpose(-1, 1)
# --> 101 x_n = self.norm(x)
#     103 if self.combine_batch_time:
#     104     x_n = x_n.reshape(shape_or)
#
# File ~/PyEnv/ecapa_venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/PyEnv/ecapa_venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/PyEnv/ecapa_venv/lib/python3.12/site-packages/torch/nn/modules/batchnorm.py:193, in _BatchNorm.forward(self, input)
#     186     bn_training = (self.running_mean is None) and (self.running_var is None)
#     188 r"""
#     189 Buffers are only updated if they are to be tracked and we are in training mode. Thus they only need to be
#     190 passed when the update should occur (i.e. in training mode when they are tracked), or when buffer stats are
#     191 used for normalization (i.e. in eval mode when buffers are not None).
#     192 """
# --> 193 return F.batch_norm(
#     194     input,
#     195     # If buffers are not to be tracked, ensure that they won't be updated
#     196     self.running_mean
#     197     if not self.training or self.track_running_stats
#     198     else None,
#     199     self.running_var if not self.training or self.track_running_stats else None,
#     200     self.weight,
#     201     self.bias,
#     202     bn_training,
#     203     exponential_average_factor,
#     204     self.eps,
#     205 )
#
# File ~/PyEnv/ecapa_venv/lib/python3.12/site-packages/torch/nn/functional.py:2822, in batch_norm(input, running_mean, running_var, weight, bias, training, momentum, eps)
#    2819 if training:
#    2820     _verify_batch_size(input.size())
# -> 2822 return torch.batch_norm(
#    2823     input,
#    2824     weight,
#    2825     bias,
#    2826     running_mean,
#    2827     running_var,
#    2828     training,
#    2829     momentum,
#    2830     eps,
#    2831     torch.backends.cudnn.enabled,
#    2832 )
#
# RuntimeError: running_mean should contain 64 elements not 8
