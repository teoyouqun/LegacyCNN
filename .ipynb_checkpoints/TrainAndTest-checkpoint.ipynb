# %%
from torchsummary import summary
from python_lib.ecapa_classifier import *
from python_lib.trainers import *
import torch
import numpy as np
import os
import h5py
from torch.utils.data import DataLoader, TensorDataset, Dataset
from torch.utils.data import random_split
from datetime import datetime

# %%
model = ECAPA_TDNN(input_size = 2, channels=[512,512,512,512,1024], lin_neurons=192, out_neurons=5, device = "cuda", metrics_type="cosine")
#model = ECAPA_TDNN(input_size = 8, lin_neurons=6, device = "cpu")
model.train()
#input_feats = torch.rand([10,2,512])
#print(input_feats)
#output = model(input_feats)
#output.shape
# Out:
# ECAPA_TDNN(
#   (blocks): ModuleList(
#     (0): TDNNBlock(
#       (conv): Conv1d(
#         (conv): Conv1d(2, 512, kernel_size=(5,), stride=(1,))
#       )
#       (activation): ReLU()
#       (norm): BatchNorm1d(
#         (norm): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): SERes2NetBlock(
#       (tdnn1): TDNNBlock(
#         (conv): Conv1d(
#           (conv): Conv1d(512, 512, kernel_size=(1,), stride=(1,))
#         )
#         (activation): ReLU()
#         (norm): BatchNorm1d(
#           (norm): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (res2net_block): Res2NetBlock(
#         (blocks): ModuleList(
#           (0-6): 7 x TDNNBlock(
#             (conv): Conv1d(
#               (conv): Conv1d(64, 64, kernel_size=(3,), stride=(1,), dilation=(2,))
#             )
#             (activation): ReLU()
#             (norm): BatchNorm1d(
#               (norm): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#       )
#       (tdnn2): TDNNBlock(
#         (conv): Conv1d(
#           (conv): Conv1d(512, 512, kernel_size=(1,), stride=(1,))
#         )
#         (activation): ReLU()
#         (norm): BatchNorm1d(
#           (norm): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (se_block): SEBlock(
#         (conv1): Conv1d(
#           (conv): Conv1d(512, 128, kernel_size=(1,), stride=(1,))
#         )
#         (relu): ReLU(inplace=True)
#         (conv2): Conv1d(
#           (conv): Conv1d(128, 512, kernel_size=(1,), stride=(1,))
#         )
#         (sigmoid): Sigmoid()
#       )
#     )
#     (2): SERes2NetBlock(
#       (tdnn1): TDNNBlock(
#         (conv): Conv1d(
#           (conv): Conv1d(512, 512, kernel_size=(1,), stride=(1,))
#         )
#         (activation): ReLU()
#         (norm): BatchNorm1d(
#           (norm): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (res2net_block): Res2NetBlock(
#         (blocks): ModuleList(
#           (0-6): 7 x TDNNBlock(
#             (conv): Conv1d(
#               (conv): Conv1d(64, 64, kernel_size=(3,), stride=(1,), dilation=(3,))
#             )
#             (activation): ReLU()
#             (norm): BatchNorm1d(
#               (norm): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#       )
#       (tdnn2): TDNNBlock(
#         (conv): Conv1d(
#           (conv): Conv1d(512, 512, kernel_size=(1,), stride=(1,))
#         )
#         (activation): ReLU()
#         (norm): BatchNorm1d(
#           (norm): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (se_block): SEBlock(
#         (conv1): Conv1d(
#           (conv): Conv1d(512, 128, kernel_size=(1,), stride=(1,))
#         )
#         (relu): ReLU(inplace=True)
#         (conv2): Conv1d(
#           (conv): Conv1d(128, 512, kernel_size=(1,), stride=(1,))
#         )
#         (sigmoid): Sigmoid()
#       )
#     )
#     (3): SERes2NetBlock(
#       (tdnn1): TDNNBlock(
#         (conv): Conv1d(
#           (conv): Conv1d(512, 512, kernel_size=(1,), stride=(1,))
#         )
#         (activation): ReLU()
#         (norm): BatchNorm1d(
#           (norm): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (res2net_block): Res2NetBlock(
#         (blocks): ModuleList(
#           (0-6): 7 x TDNNBlock(
#             (conv): Conv1d(
#               (conv): Conv1d(64, 64, kernel_size=(3,), stride=(1,), dilation=(4,))
#             )
#             (activation): ReLU()
#             (norm): BatchNorm1d(
#               (norm): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#       )
#       (tdnn2): TDNNBlock(
#         (conv): Conv1d(
#           (conv): Conv1d(512, 512, kernel_size=(1,), stride=(1,))
#         )
#         (activation): ReLU()
#         (norm): BatchNorm1d(
#           (norm): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (se_block): SEBlock(
#         (conv1): Conv1d(
#           (conv): Conv1d(512, 128, kernel_size=(1,), stride=(1,))
#         )
#         (relu): ReLU(inplace=True)
#         (conv2): Conv1d(
#           (conv): Conv1d(128, 512, kernel_size=(1,), stride=(1,))
#         )
#         (sigmoid): Sigmoid()
#       )
#     )
#   )
#   (mfa): TDNNBlock(
#     (conv): Conv1d(
#       (conv): Conv1d(1536, 1024, kernel_size=(1,), stride=(1,))
#     )
#     (activation): ReLU()
#     (norm): BatchNorm1d(
#       (norm): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (asp): AttentiveStatisticsPooling(
#     (tdnn): TDNNBlock(
#       (conv): Conv1d(
#         (conv): Conv1d(3072, 128, kernel_size=(1,), stride=(1,))
#       )
#       (activation): ReLU()
#       (norm): BatchNorm1d(
#         (norm): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (tanh): Tanh()
#     (conv): Conv1d(
#       (conv): Conv1d(128, 1024, kernel_size=(1,), stride=(1,))
#     )
#   )
#   (asp_bn): BatchNorm1d(
#     (norm): BatchNorm1d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (fc): Conv1d(
#     (conv): Conv1d(2048, 192, kernel_size=(1,), stride=(1,))
#   )
#   (probabilities): Classifier()
# )

# %%
with h5py.File('../RadChar-Tiny.h5', 'r') as f:
    # Print the dataset names
    print(list(f.keys())) # OUT: ['iq', 'labels']
    
    # Get a reference to the dataset
    h5_iqs = f['iq'] 
    h5_labels = f['labels'] 
    
    # Print the shape of the dataset
    # print(h5_iqs.shape) # OUT: (50000, 512)
    # print(h5_labels.shape) # OUT: (50000,)
    
    # Print the contents of the dataset
    loaded_h5_iqs = h5_iqs[...] # IQ data
    loaded_h5_labels = h5_labels[...] # Label data

# Temporary fix to deal with IQ data
temp_iq_data = torch.tensor(loaded_h5_iqs)
t_iq_real = temp_iq_data.real.float()
t_iq_imag = temp_iq_data.imag.float()
t_iq_data = torch.stack([t_iq_real, t_iq_imag], dim = 1)
print(t_iq_data.shape)

index = loaded_h5_labels['index']
signal_type = loaded_h5_labels['signal_type']
t_index = torch.tensor(index, dtype=torch.int64)
t_signal_type = torch.tensor(signal_type, dtype=torch.int64)
combined = torch.stack([t_index, t_signal_type], dim=1)
dataset = TensorDataset(t_iq_data, combined)
# Out:
# ['iq', 'labels']
# torch.Size([50000, 2, 512])

# %%
# total size
total_size = 50000
train_size = 45000
val_size = total_size - train_size
# batch size
batch_size = 32

# split
train_dataset, val_dataset = random_split(
    dataset, [train_size, val_size],
    generator=torch.Generator().manual_seed(42)  # for reproducibility
)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

print("Done")
# Out:
# Done

# %% [markdown]
# # Run the below only for training, you can vary num_epochs accordingly

# %%
model.train()
training = BaseTrainer(model)
training._train(train_loader, num_epochs=2)

# Get current date and time formatted as YYYY-MM-DD_HH-MM-SS
now = datetime.now()
timestamp = now.strftime("%Y%m%d_%H:%M:%S")
filename = f"model_weights_{timestamp}.pt"
training.save_model(filename, model)

# %% [markdown]
# # Run the below only for testing, you can change the loaded .pt file accordingly

# %%
checkpoint = torch.load("./model_weights_.pt", weights_only=True, map_location='cpu')
model_test = ECAPA_TDNN(input_size = 2, channels=[512,512,512,512,1024], lin_neurons=192, out_neurons=5, device = "cuda", metrics_type="cosine")
model_test.load_state_dict(checkpoint)
model_test.to('cuda')
model_test.eval()
testing = BaseTrainer(model_test)
testing._test(val_loader)
# Out:
# Batch No. 1/157:   0%|                                                                          | 0/157 [00:00<?, ?it/s]
# Batch No. 1/157:   0%|                                                                          | 0/157 [00:02<?, ?it/s]
# Batch No. 2/157:   0%|                                                                          | 0/157 [00:00<?, ?it/s]
#
# Batch No. 3/157:   0%|                                                                          | 0/157 [00:00<?, ?it/s]
# Batch No. 4/157:   0%|                                                                          | 0/157 [00:00<?, ?it/s]
#
# Batch No. 5/157:   0%|                                                                          | 0/157 [00:00<?, ?it/s]
# Batch No. 6/157:   0%|                                                                          | 0/157 [00:00<?, ?it/s]
#
# Batch No. 7/157:   0%|                                                                          | 0/157 [00:00<?, ?it/s]
# Batch No. 8/157:   0%|                                                                          | 0/157 [00:00<?, ?it/s]
#
# Batch No. 9/157:   0%|                                                                          | 0/157 [00:00<?, ?it/s]
# Batch No. 10/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
#
# Batch No. 11/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
# Batch No. 12/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
#
# Batch No. 13/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
# Batch No. 14/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
#
# Batch No. 15/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
# Batch No. 16/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
#
# Batch No. 17/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
# Batch No. 18/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
#
# Batch No. 19/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
# Batch No. 20/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
#
# Batch No. 21/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
# Batch No. 22/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
#
# Batch No. 23/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
# Batch No. 24/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
#
# Batch No. 25/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
# Batch No. 26/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
#
# Batch No. 27/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
# Batch No. 28/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
#
# Batch No. 29/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
# Batch No. 30/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
#
# Batch No. 31/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
# Batch No. 32/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
#
# Batch No. 33/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
# Batch No. 34/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
#
# Batch No. 35/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
# Batch No. 36/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
#
# Batch No. 37/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
# Batch No. 38/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
#
# Batch No. 39/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
# Batch No. 40/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
#
# Batch No. 41/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
# Batch No. 42/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
#
# Batch No. 43/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
# Batch No. 44/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
#
# Batch No. 45/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
# Batch No. 46/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
#
# Batch No. 47/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
# Batch No. 48/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
#
# Batch No. 49/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
# Batch No. 50/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
#
# Batch No. 51/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
# Batch No. 52/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
#
# Batch No. 53/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
# Batch No. 54/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
#
# Batch No. 55/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
# Batch No. 56/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
#
# Batch No. 57/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
# Batch No. 58/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
#
# Batch No. 59/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
# Batch No. 60/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
#
# Batch No. 61/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
# Batch No. 62/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
#
# Batch No. 63/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
# Batch No. 64/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
#
# Batch No. 65/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
# Batch No. 66/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
#
# Batch No. 67/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
# Batch No. 68/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
#
# Batch No. 69/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
# Batch No. 70/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
#
# Batch No. 71/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
# Batch No. 72/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
#
# Batch No. 73/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
# Batch No. 74/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
#
# Batch No. 75/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
# Batch No. 76/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
#
# Batch No. 77/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
# Batch No. 78/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
#
# Batch No. 79/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
# Batch No. 80/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
#
# Batch No. 81/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
# Batch No. 82/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
#
# Batch No. 83/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
# Batch No. 84/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
#
# Batch No. 85/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
# Batch No. 86/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
#
# Batch No. 87/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
# Batch No. 88/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
#
# Batch No. 89/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
# Batch No. 90/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
#
# Batch No. 91/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
# Batch No. 92/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
#
# Batch No. 93/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
# Batch No. 94/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
#
# Batch No. 95/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
# Batch No. 96/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
#
# Batch No. 97/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
# Batch No. 98/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
#
# Batch No. 99/157:   0%|                                                                         | 0/157 [00:00<?, ?it/s]
# Batch No. 100/157:   0%|                                                                        | 0/157 [00:00<?, ?it/s]
#
# Batch No. 101/157:   0%|                                                                        | 0/157 [00:00<?, ?it/s]
# Batch No. 102/157:   0%|                                                                        | 0/157 [00:00<?, ?it/s]
#
# Batch No. 103/157:   0%|                                                                        | 0/157 [00:00<?, ?it/s]
# Batch No. 104/157:   0%|                                                                        | 0/157 [00:00<?, ?it/s]
#
# Batch No. 105/157:   0%|                                                                        | 0/157 [00:00<?, ?it/s]
# Batch No. 106/157:   0%|                                                                        | 0/157 [00:00<?, ?it/s]
#
# Batch No. 107/157:   0%|                                                                        | 0/157 [00:00<?, ?it/s]
# Batch No. 108/157:   0%|                                                                        | 0/157 [00:00<?, ?it/s]
#
# Batch No. 109/157:   0%|                                                                        | 0/157 [00:00<?, ?it/s]
# Batch No. 110/157:   0%|                                                                        | 0/157 [00:00<?, ?it/s]
#
# Batch No. 111/157:   0%|                                                                        | 0/157 [00:00<?, ?it/s]
# Batch No. 112/157:   0%|                                                                        | 0/157 [00:00<?, ?it/s]
#
# Batch No. 113/157:   0%|                                                                        | 0/157 [00:00<?, ?it/s]
# Batch No. 114/157:   0%|                                                                        | 0/157 [00:00<?, ?it/s]
#
# Batch No. 115/157:   0%|                                                                        | 0/157 [00:00<?, ?it/s]
# Batch No. 116/157:   0%|                                                                        | 0/157 [00:00<?, ?it/s]
#
# Batch No. 117/157:   0%|                                                                        | 0/157 [00:00<?, ?it/s]
# Batch No. 118/157:   0%|                                                                        | 0/157 [00:00<?, ?it/s]
#
# Batch No. 119/157:   0%|                                                                        | 0/157 [00:00<?, ?it/s]
# Batch No. 120/157:   0%|                                                                        | 0/157 [00:00<?, ?it/s]
#
# Batch No. 121/157:   0%|                                                                        | 0/157 [00:00<?, ?it/s]
# Batch No. 122/157:   0%|                                                                        | 0/157 [00:00<?, ?it/s]
#
# Batch No. 123/157:   0%|                                                                        | 0/157 [00:00<?, ?it/s]
# Batch No. 124/157:   0%|                                                                        | 0/157 [00:00<?, ?it/s]
#
# Batch No. 125/157:   0%|                                                                        | 0/157 [00:00<?, ?it/s]
# Batch No. 126/157:   0%|                                                                        | 0/157 [00:00<?, ?it/s]
#
# Batch No. 127/157:   0%|                                                                        | 0/157 [00:00<?, ?it/s]
# Batch No. 128/157:   0%|                                                                        | 0/157 [00:00<?, ?it/s]
#
# Batch No. 129/157:   0%|                                                                        | 0/157 [00:00<?, ?it/s]
# Batch No. 130/157:   0%|                                                                        | 0/157 [00:00<?, ?it/s]
#
# Batch No. 131/157:   0%|                                                                        | 0/157 [00:00<?, ?it/s]
# Batch No. 132/157:   0%|                                                                        | 0/157 [00:00<?, ?it/s]
#
# Batch No. 133/157:   0%|                                                                        | 0/157 [00:00<?, ?it/s]
# Batch No. 134/157:   0%|                                                                        | 0/157 [00:00<?, ?it/s]
#
# Batch No. 135/157:   0%|                                                                        | 0/157 [00:00<?, ?it/s]
# Batch No. 136/157:   0%|                                                                        | 0/157 [00:00<?, ?it/s]
#
# Batch No. 137/157:   0%|                                                                        | 0/157 [00:00<?, ?it/s]
# Batch No. 138/157:   0%|                                                                        | 0/157 [00:00<?, ?it/s]
#
# Batch No. 139/157:   0%|                                                                        | 0/157 [00:00<?, ?it/s]
# Batch No. 140/157:   0%|                                                                        | 0/157 [00:00<?, ?it/s]
#
# Batch No. 141/157:   0%|                                                                        | 0/157 [00:00<?, ?it/s]
# Batch No. 142/157:   0%|                                                                        | 0/157 [00:00<?, ?it/s]
#
# Batch No. 143/157:   0%|                                                                        | 0/157 [00:00<?, ?it/s]
# Batch No. 144/157:   0%|                                                                        | 0/157 [00:00<?, ?it/s]
#
# Batch No. 145/157:   0%|                                                                        | 0/157 [00:00<?, ?it/s]
# Batch No. 146/157:   0%|                                                                        | 0/157 [00:00<?, ?it/s]
#
# Batch No. 147/157:   0%|                                                                        | 0/157 [00:00<?, ?it/s]
# Batch No. 148/157:   0%|                                                                        | 0/157 [00:00<?, ?it/s]
#
# Batch No. 149/157:   0%|                                                                        | 0/157 [00:00<?, ?it/s]
# Batch No. 150/157:   0%|                                                                        | 0/157 [00:00<?, ?it/s]
#
# Batch No. 151/157:   0%|                                                                        | 0/157 [00:00<?, ?it/s]
# Batch No. 152/157:   0%|                                                                        | 0/157 [00:00<?, ?it/s]
#
# Batch No. 153/157:   0%|                                                                        | 0/157 [00:00<?, ?it/s]
# Batch No. 154/157:   0%|                                                                        | 0/157 [00:00<?, ?it/s]
#
# Batch No. 155/157:   0%|                                                                        | 0/157 [00:00<?, ?it/s]
# Batch No. 156/157:   0%|                                                                        | 0/157 [00:00<?, ?it/s]
# Batch No. 157/157:   0%|                                                                        | 0/157 [00:00<?, ?it/s]
# Test set: Average loss: 0.9321, Accuracy: 4245/5000 (85%)
#
# Time : 22.786937364959158
# array([[956.,  15.,  28.,  34.,  30.,   0.],
#        [  2., 831.,  24.,  25.,  24.,   0.],
#        [  3.,  57., 782.,  48.,  49.,   0.],
#        [ 46.,  89., 129., 855., 112.,   0.],
#        [  0.,  15.,  16.,   9., 821.,   0.],
#        [  0.,   0.,   0.,   0.,   0.,   0.]])
